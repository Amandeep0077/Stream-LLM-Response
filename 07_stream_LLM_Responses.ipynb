# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
question = "Act as senior scientist, explain process of photosynthesis with example as you teching 5th class student?"

# %%
response = llm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# ### 🌱 **Photosynthesis – The Plant’s Super‑Power**
# *Explained by a Senior Scientist, for a 5th‑class superstar*
#
# ---
#
# #### 1. **What is Photosynthesis?**
# Think of a plant as a **tiny kitchen** that makes its own food.
# - **Ingredients:**
#   - **Sunlight** – the chef’s energy source.
#   - **Water** – from the soil.
#   - **Carbon dioxide (CO₂)** – the “air‑ingredient” that plants breathe in.
#
# - **What the plant makes:**
#   - **Glucose** – a sweet sugar that fuels the plant (like a snack for it).
#   - **Oxygen (O₂)** – the plant’s *gift* to us, the air we breathe.
#
# ---
#
# #### 2. **The “Kitchen” Inside a Leaf**
#
# | Part of the leaf | What it does |
# |------------------|--------------|
# | **Chloroplast** | The kitchen’s “microwave” – it catches sunlight. |
# | **Chlorophyll** | The green pigment that gives leaves their color; it’s the “solar panel” that captures light. |
# | **Stomata** | Tiny “windows” that let CO₂ in and O₂ out. |
#
# ---
#
# #### 3. **Step‑by‑Step: The Plant’s Recipe**
#
# 1. **Light‑Dependent Reactions**
#    - Sunlight hits chlorophyll → energy is captured.
#    - Water molecules (H₂O) are split into **hydrogen** and **oxygen**.
#    - Oxygen is released as bubbles (that’s the *O₂* we breathe).
#    - The energy stored becomes **ATP** (energy “currency”) and **NADPH** (a “helper” that carries electrons).
#
# 2. **Light‑Independent Reactions (Calvin Cycle)**
#    - ATP + NADPH + CO₂ → **Glucose** (C₆H₁₂O₆).
#    - This happens in the chloroplast’s **stroma** (the “mixing bowl”).
#
# > **Quick analogy:**
# > *Think of sunlight as the chef’s stove, water as the water you pour into the pot, CO₂ as the flour, and the final dish is a sweet cake called glucose.*
#
# ---
#
# #### 4. **A Real‑World Example: The Sunflower**
#
# - **Sunflower’s “Factory”**
#   - Its big, bright leaves soak up sunlight.
#   - The roots drink water from the soil.
#   - The sunflower’s stomata pull in CO₂ from the air.
#
# - **What Happens Inside**
#   1. Sunlight powers the chloroplasts.
#   2. Water is split → O₂ bubbles rise (you can see them if you put a leaf in a glass of water under a lamp!).
#   3. CO₂ is fixed into glucose, which the sunflower uses to grow tall, make seeds, and produce that gorgeous yellow bloom.
#
# ---
#
# #### 5. **Why Is Photosynthesis Super‑Important?**
#
# | Benefit | How it Helps Us |
# |---------|-----------------|
# | **Oxygen Production** | Keeps the air breathable for humans and animals. |
# | **Food Source** | Plants are the base of almost every food chain. |
# | **Carbon Sequestration** | Plants absorb CO₂, helping to keep the planet’s climate balanced. |
#
# ---
#
# #### 6. **Fun Classroom Experiment (No Big Equipment Needed)**
#
# **What you’ll need:**
# - A fresh leaf (from a tree or a potted plant).
# - A clear glass or jar.
# - Water.
# - A sunny window or a lamp.
#
# **Steps:**
# 1. Fill the glass with water.
# 2. Place the leaf in the water.
# 3. Put the glass near sunlight (or under the lamp).
# 4. After 10–15 minutes, you might see tiny bubbles forming on the leaf’s underside.
# 5. Those bubbles are **oxygen** produced by photosynthesis!
#
# **Why it works:**
# - The leaf’s chloroplasts are capturing light, splitting water, and releasing oxygen.
#
# ---
#
# #### 7. **Quick Quiz – Test Your Knowledge!**
#
# 1. **What three “ingredients” does a plant need to do photosynthesis?**
#    *Answer: Sunlight, water, and carbon dioxide.*
#
# 2. **What is the “sweet” food that plants make?**
#    *Answer: Glucose.*
#
# 3. **Which part of the leaf lets the plant take in CO₂?**
#    *Answer: Stomata.*
#
# 4. **What useful gas does a plant give us back?**
#    *Answer: Oxygen.*
#
# ---
#
# #### 8. **Take‑Away Message**
#
# - Plants are **natural chefs** that turn sunlight, water, and air into food and oxygen.
# - Every time you see a green leaf, remember it’s a tiny factory working hard to keep life on Earth thriving.
#
# Happy exploring, future scientists! 🌞🌿
